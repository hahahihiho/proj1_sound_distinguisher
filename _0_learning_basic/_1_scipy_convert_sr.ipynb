# %% [markdown]
# # scipy sampling rate modify
# * interpolate

# %%
import numpy as np
from scipy.io import wavfile
from scipy import interpolate

NEW_SAMPLERATE = 44100*2

old_samplerate, old_audio = wavfile.read("../m4a_files/이봐징징이.wav")

if old_samplerate != NEW_SAMPLERATE:
    duration = old_audio.shape[0] / old_samplerate

    time_old  = np.linspace(0, duration, old_audio.shape[0])
    time_new  = np.linspace(0, duration, int(old_audio.shape[0] * NEW_SAMPLERATE / old_samplerate))

    interpolator = interpolate.interp1d(time_old, old_audio.T)
    new_audio = interpolator(time_new).T

    wavfile.write("./sound_data/out.wav", NEW_SAMPLERATE, np.round(new_audio).astype(old_audio.dtype))

# %%
a = wavfile.read('sound_data/out.wav')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(old_audio)

# %%
plt.plot(old_audio[50000:50010])

# %%
plt.plot(a[1][100000:100020])
